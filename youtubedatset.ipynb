# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\alokd\\Downloads\\Global YouTube Statistics.csv", encoding='ISO-8859-1')

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df.tail()
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 990   991             Natan por Aï¿     12300000  9.029610e+09
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category                     Title  uploads         Country  \
# 990          Sports             Natan por Aï¿     1200          Brazil
# 991  People & Blogs  Free Fire India Official     1500           India
# 992             NaN               HybridPanda     2452  United Kingdom
# 993          Gaming               RobTopGames       39          Sweden
# 994          Comedy              Make Joke Of       62           India
#
#     Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 990           BR  Entertainment  ...                      700000.0
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (995, 28)

# %%
df.size
# Out:
# 27860

# %%
rows=df.count()
print(rows)
# Out:
# rank                                       995
# Youtuber                                   995
# subscribers                                995
# video views                                995
# category                                   949
# Title                                      995
# uploads                                    995
# Country                                    873
# Abbreviation                               873
# channel_type                               965
# video_views_rank                           994
# country_rank                               879
# channel_type_rank                          962
# video_views_for_the_last_30_days           939
# lowest_monthly_earnings                    995
# highest_monthly_earnings                   995
# lowest_yearly_earnings                     995
# highest_yearly_earnings                    995
# subscribers_for_last_30_days               658
# created_year                               990
# ...

# %%
rows.mean()
# Out:
# 937.2857142857143

# %%
rows.median()
# Out:
# 977.5

# %%
rows.std()
# Out:
# 77.36821873250842

# %%
df["subscribers"].max
# Out:
# <bound method Series.max of 0      245000000
# 1      170000000
# 2      166000000
# 3      162000000
# 4      159000000
#          ...
# 990     12300000
# 991     12300000
# 992     12300000
# 993     12300000
# 994     12300000
# Name: subscribers, Length: 995, dtype: int64>

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
df=pd.DataFrame(df)

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %% [markdown]
# # Bar Graph

# %%
y=df["video views"]
x=df["subscribers"]
plt.bar(x,y,label="Youtuber",color="green")
plt.xlabel("subscribers")
plt.ylabel("video views")
plt.title("YOUTUBE VIEWS DATASET")
plt.show()

# %%
x=df["subscribers"]
plt.hist(x,bins=None,histtype="bar",rwidth=0.5,color='blue')
# Out:
# (array([889.,  75.,  15.,   7.,   4.,   0.,   4.,   0.,   0.,   1.]),
#  array([1.2300e+07, 3.5570e+07, 5.8840e+07, 8.2110e+07, 1.0538e+08,
#         1.2865e+08, 1.5192e+08, 1.7519e+08, 1.9846e+08, 2.2173e+08,
#         2.4500e+08]),
#  <BarContainer object of 10 artists>)

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %% [markdown]
# # Pie Chart

# %%
slices=[45,24,34,16]
depts=["Rank","Subscribers","Views","Uploads"]
cols=["violet","indigo","green","blue"]
plt.pie(slices,labels=depts,colors=cols,startangle=90,explode=(0,0,0,0.2),shadow=True,autopct="%.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1ff174dd040>,
# ...
#  [Text(-1.0203850383478072, 0.41087026360634094, 'Rank'),
#   Text(-0.14477831018630014, -1.090430759333026, 'Subscribers'),
#   Text(1.083844189970977, -0.1878344267331133, 'Views'),
#   Text(0.5329345294849823, 1.1857406070817602, 'Uploads')],
#  [Text(-0.5565736572806221, 0.22411105287618593, '37.8%'),
#   Text(-0.07896998737434552, -0.5947804141816505, '20.2%'),
#   Text(0.5911877399841692, -0.10245514185442543, '28.6%'),
#   Text(0.32795971045229677, 0.7296865274349291, '13.4%')])

# %%
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %% [markdown]
# # Line Chart

# %%
y=df["rank"]
x=df["uploads"]
plt.plot(x,y,"black")

# %% [markdown]
# # Distribution Plot

# %%
sns.displot(data=df,x="subscribers_for_last_30_days",bins=10,kde=True,color="red")

# %% [markdown]
# # REGRESSION PLOT

# %%
sns.regplot(y="subscribers",x="video views",data=df)
# Out:
# <Axes: xlabel='video views', ylabel='subscribers'>

# %% [markdown]
# # Box Plot

# %%
sns.pairplot(df,hue="Gross tertiary education enrollment (%)")
